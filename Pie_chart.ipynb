# %% [markdown]
# <a href="https://colab.research.google.com/github/mengyush/data-science/blob/main/pie_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.figsize'] = (10,7)

# %% [markdown]
# ### Draw pie chart to track down home expenses

# %%
exp_vals = [1400, 600, 300, 410, 250]
exp_labels = ["Home Rent", "Food", "Phone / Internet Bill", "Car ", "Other Utilities"]
plt.pie(exp_vals, labels=exp_labels);

# %% [markdown]
# ### Show percentages for every pie. Specify radius to increase chart size

# %%
plt.pie(exp_vals, labels=exp_labels, shadow=True, autopct='%1.1f%%', radius=1.5);

# %% [markdown]
# ### Explode

# %%
plt.pie(exp_vals, labels=exp_labels, shadow=True, autopct='%1.1f%%', explode=[0,0,0,0.1,0.2]);

# %% [markdown]
# ### counterclock and angle properties

# %%
plt.pie(exp_vals, labels=exp_labels, shadow=True, autopct='%1.1f%%', explode=[0,0,0,0.1,0.2], counterclock=True, startangle=45);
